# %%
# !pip install transformers
# !pip install torch

# %%
from transformers import pipeline

# Load the model
pipe = pipeline('image-classification', model="prithivMLmods/Deep-Fake-Detector-v2-Model", device=0)

# %%
# Predict on an image
result = pipe("smex.jpg")
print(result)

# %%
fattest = pipe("fatlady.jpg")
print(fattest)

# %%
aminsexy = pipe("aminsexy.jpg")
print(aminsexy)

# %%
aminnotsexy = pipe("aminnotsexy.jpg")
print(aminnotsexy)

# %%
aminsmiley = pipe("aminsmiley.jpg")
print(aminsmiley)

# %%
amincultured = pipe("amincultured.jpg")
print(amincultured)

# %%
osssexy = pipe("osssexy.jpg")
print(osssexy)

# %%
boodyfake = pipe("boodyfake.jpg")
print(boodyfake)

# %%
amintoosexy = pipe("amintoosexy.jpg")
print(amintoosexy)

# %%
aminheaven = pipe("aminheaven.jpg")
print(aminheaven)

# %%
basio = pipe("basio.jpg")
print(basio)

# %%
smexes = pipe("smexes.jpg")
print(smexes)

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

DeepfakeDetViT  = pipeline("image-classification", model="buildborderless/CommunityForensics-DeepfakeDet-ViT")
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\torchvision\io\image.py:13: UserWarning: Failed to load image Python extension: '[WinError 127] The specified procedure could not be found'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(
# WARNING:tensorflow:From c:\ProgramData\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# c:\ProgramData\anaconda3\Lib\site-packages\torchvision\datapoints\__init__.py:12: UserWarning: The torchvision.datapoints and torchvision.transforms.v2 namespaces are still Beta. While we do not expect major breaking changes, some APIs may still change according to user feedback. Please submit any feedback you may have in this issue: https://github.com/pytorch/vision/issues/6753, and you can also check out https://github.com/pytorch/vision/issues/7319 to learn more about the APIs that we suspect might involve future changes. You can silence this warning by calling torchvision.disable_beta_transforms_warning().
#   warnings.warn(_BETA_TRANSFORMS_WARNING)
# c:\ProgramData\anaconda3\Lib\site-packages\torchvision\transforms\v2\__init__.py:54: UserWarning: The torchvision.datapoints and torchvision.transforms.v2 namespaces are still Beta. While we do not expect major breaking changes, some APIs may still change according to user feedback. Please submit any feedback you may have in this issue: https://github.com/pytorch/vision/issues/6753, and you can also check out https://github.com/pytorch/vision/issues/7319 to learn more about the APIs that we suspect might involve future changes. You can silence this warning by calling torchvision.disable_beta_transforms_warning().
#   warnings.warn(_BETA_TRANSFORMS_WARNING)
# Fast image processor class <class 'transformers.models.vit.image_processing_vit_fast.ViTImageProcessorFast'> is available for this model. Using slow image processor class. To use the fast image processor class set `use_fast=True`.
# Device set to use cpu

# %%
#loop over the images in the current directory and predict on them
# resize all images to 384*384 before predicting
# the model uses a path only, so we need to read the image, resize it, and then pass it to the model


import os
import cv2
from PIL import Image
import numpy as np

for filename in os.listdir():
    if (filename.endswith(".jpg") or filename.endswith(".png")) and filename != "temp.jpg":
        img = cv2.imread(filename)
        img = cv2.resize(img, (384, 384))
        # Convert BGR to RGB and pass directly as PIL Image
        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        pil_image = Image.fromarray(img_rgb)

        result = DeepfakeDetViT(pil_image)

        print(f"{filename}: {result}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 19
#      16 img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#      17 pil_image = Image.fromarray(img_rgb)
# ---> 19 result = DeepfakeDetViT(pil_image)
#      21 print(f"{filename}: {result}")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\transformers\pipelines\image_classification.py:177, in ImageClassificationPipeline.__call__(self, inputs, **kwargs)
#     175 if inputs is None:
#     176     raise ValueError("Cannot call the image-classification pipeline without an inputs argument!")
# --> 177 return super().__call__(inputs, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\transformers\pipelines\base.py:1379, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1371     return next(
#    1372         iter(
#    1373             self.get_iterator(
#    (...)
#    1376         )
#    1377     )
#    1378 else:
# -> 1379     return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\transformers\pipelines\base.py:1386, in Pipeline.run_single(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1384 def run_single(self, inputs, preprocess_params, forward_params, postprocess_params):
#    1385     model_inputs = self.preprocess(inputs, **preprocess_params)
# -> 1386     model_outputs = self.forward(model_inputs, **forward_params)
#    1387     outputs = self.postprocess(model_outputs, **postprocess_params)
#    1388     return outputs
#
# File ~\AppData\Roaming\Python\Python311\site-packages\transformers\pipelines\base.py:1286, in Pipeline.forward(self, model_inputs, **forward_params)
#    1284     with inference_context():
#    1285         model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1286         model_outputs = self._forward(model_inputs, **forward_params)
#    1287         model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1288 else:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\transformers\pipelines\image_classification.py:187, in ImageClassificationPipeline._forward(self, model_inputs)
#     186 def _forward(self, model_inputs):
# --> 187     model_outputs = self.model(**model_inputs)
#     188     return model_outputs
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\transformers\models\vit\modeling_vit.py:833, in ViTForImageClassification.forward(self, pixel_values, head_mask, labels, output_attentions, output_hidden_states, interpolate_pos_encoding, return_dict)
#     825 r"""
#     826 labels (`torch.LongTensor` of shape `(batch_size,)`, *optional*):
#     827     Labels for computing the image classification/regression loss. Indices should be in `[0, ...,
#     828     config.num_labels - 1]`. If `config.num_labels == 1` a regression loss is computed (Mean-Square loss), If
#     829     `config.num_labels > 1` a classification loss is computed (Cross-Entropy).
#     830 """
#     831 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# --> 833 outputs = self.vit(
#     834     pixel_values,
#     835     head_mask=head_mask,
#     836     output_attentions=output_attentions,
#     837     output_hidden_states=output_hidden_states,
#     838     interpolate_pos_encoding=interpolate_pos_encoding,
#     839     return_dict=return_dict,
#     840 )
#     842 sequence_output = outputs[0]
#     844 logits = self.classifier(sequence_output[:, 0, :])
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\transformers\models\vit\modeling_vit.py:612, in ViTModel.forward(self, pixel_values, bool_masked_pos, head_mask, output_attentions, output_hidden_states, interpolate_pos_encoding, return_dict)
#     609 if pixel_values.dtype != expected_dtype:
#     610     pixel_values = pixel_values.to(expected_dtype)
# --> 612 embedding_output = self.embeddings(
#     613     pixel_values, bool_masked_pos=bool_masked_pos, interpolate_pos_encoding=interpolate_pos_encoding
#     614 )
#     616 encoder_outputs = self.encoder(
#     617     embedding_output,
#     618     head_mask=head_mask,
#    (...)
#     621     return_dict=return_dict,
#     622 )
#     623 sequence_output = encoder_outputs[0]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\transformers\models\vit\modeling_vit.py:124, in ViTEmbeddings.forward(self, pixel_values, bool_masked_pos, interpolate_pos_encoding)
#     117 def forward(
#     118     self,
#     119     pixel_values: torch.Tensor,
#     120     bool_masked_pos: Optional[torch.BoolTensor] = None,
#     121     interpolate_pos_encoding: bool = False,
#     122 ) -> torch.Tensor:
#     123     batch_size, num_channels, height, width = pixel_values.shape
# --> 124     embeddings = self.patch_embeddings(pixel_values, interpolate_pos_encoding=interpolate_pos_encoding)
#     126     if bool_masked_pos is not None:
#     127         seq_length = embeddings.shape[1]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\transformers\models\vit\modeling_vit.py:179, in ViTPatchEmbeddings.forward(self, pixel_values, interpolate_pos_encoding)
#     177 if not interpolate_pos_encoding:
#     178     if height != self.image_size[0] or width != self.image_size[1]:
# --> 179         raise ValueError(
#     180             f"Input image size ({height}*{width}) doesn't match model"
#     181             f" ({self.image_size[0]}*{self.image_size[1]})."
#     182         )
#     183 embeddings = self.projection(pixel_values).flatten(2).transpose(1, 2)
#     184 return embeddings
#
# ValueError: Input image size (440*440) doesn't match model (384*384).
