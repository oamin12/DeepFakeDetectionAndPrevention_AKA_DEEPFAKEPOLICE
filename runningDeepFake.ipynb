# %%
# !pip install transformers torch datasets huggingface_hub scipy

# %%
# !pip install scikit-image scipy h5py opencv-python efficientnet-pytorch einops tensorboardx timm

# %%
# from huggingface_hub import login as huglogin
# huglogin("INSERT TOKEN HERE")

# %%
from datasets import load_dataset

# Login using e.g. `huggingface-cli login` to access this dataset
# ds = load_dataset("MBZUAI/DeepfakeJudge-Dataset")
# fyha non-human

# ds = load_dataset("sofia-ol/MAHE_deepfake_recognition_dataset")
# fyha non-human

# ds = load_dataset("dappai/Deepfake-vs-Real-v2")
# sus bs human bs

# ds = load_dataset("ts0pwo/20K_real_and_deepfake_images")
# a8labha humans, id say about 8/9 menha, momkn ntane4ha lw el ba2y a5ad wa2t asln

# %%
# from pathlib import Path
# from huggingface_hub import snapshot_download

# repo_id = "dappai/Deepfake-vs-Real-v2"

# # Create: ./Datasets/Deepfake-vs-Real-v2
# local_dir = Path.cwd() / "Datasets" / "Deepfake-vs-Real-v2"
# local_dir.mkdir(parents=True, exist_ok=True)

# downloaded_path = snapshot_download(
#     repo_id=repo_id,
#     repo_type="dataset",
#     local_dir=str(local_dir),
#     local_dir_use_symlinks=False  # put real files there
# )

# print("Downloaded to:", downloaded_path)

# %%
# from pathlib import Path
# from huggingface_hub import snapshot_download

# repo_id = "ts0pwo/20K_real_and_deepfake_images"

# # Create: ./Datasets/20K_real_and_deepfake_images
# local_dir = Path.cwd() / "Datasets" / "20K_real_and_deepfake_images"
# local_dir.mkdir(parents=True, exist_ok=True)

# downloaded_path = snapshot_download(
#     repo_id=repo_id,
#     repo_type="dataset",
#     local_dir=str(local_dir),
#     local_dir_use_symlinks=False  # put real files there
# )

# print("Downloaded to:", downloaded_path)

# %%
from transformers import pipeline

# Load the model
pipe = pipeline('image-classification', model="prithivMLmods/Deep-Fake-Detector-v2-Model", device=0)
# model ay kalam, metala3 kolo fake

# %%
# # Use a pipeline as a high-level helper
# from transformers import pipeline

# from transformers import AutoImageProcessor
# processor = AutoImageProcessor.from_pretrained("buildborderless/CommunityForensics-DeepfakeDet-ViT")
# processor.size = {"height": 384, "width": 384}
# DeepfakeDetViT  = pipeline("image-classification", model="buildborderless/CommunityForensics-DeepfakeDet-ViT", image_processor=processor)

from transformers import pipeline

DeepfakeDetViT = pipeline("image-classification", model="prithivMLmods/Deep-Fake-Detector-v2-Model")
# Out:
# Loading weights:   0%|          | 0/200 [00:00<?, ?it/s]

# %%
#loop over the images in the current directory and predict on them
# resize all images to 384*384 before predicting
# the model uses a path only, so we need to read the image, resize it, and then pass it to the model


import os
import cv2
from PIL import Image
import numpy as np

directory = "Test"
for filename in os.listdir(directory):
    if (filename.endswith(".jpg") or filename.endswith(".png")) and filename != "temp.jpg":
        img = cv2.imread(os.path.join(directory, filename))
        img = cv2.resize(img, (224, 224))
        # Convert BGR to RGB and pass directly as PIL Image
        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        pil_image = Image.fromarray(img_rgb)

        result = DeepfakeDetViT(pil_image)

        print(f"{filename}: {result}")
# Out:
# fake (1).jpg: [{'label': 'Realism', 'score': 0.8369920253753662}, {'label': 'Deepfake', 'score': 0.1630079597234726}]
# fake (10).jpg: [{'label': 'Deepfake', 'score': 0.6612891554832458}, {'label': 'Realism', 'score': 0.33871084451675415}]
# fake (11).jpg: [{'label': 'Realism', 'score': 0.6852515935897827}, {'label': 'Deepfake', 'score': 0.3147484064102173}]
# fake (12).jpg: [{'label': 'Deepfake', 'score': 0.6940791010856628}, {'label': 'Realism', 'score': 0.30592086911201477}]
# fake (13).jpg: [{'label': 'Deepfake', 'score': 0.6646564602851868}, {'label': 'Realism', 'score': 0.33534353971481323}]
# fake (14).jpg: [{'label': 'Deepfake', 'score': 0.7090709209442139}, {'label': 'Realism', 'score': 0.2909291386604309}]
# fake (15).jpg: [{'label': 'Deepfake', 'score': 0.5479244589805603}, {'label': 'Realism', 'score': 0.4520755410194397}]
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# fake (16).jpg: [{'label': 'Realism', 'score': 0.8977303504943848}, {'label': 'Deepfake', 'score': 0.10226963460445404}]
# fake (17).jpg: [{'label': 'Realism', 'score': 0.9056609272956848}, {'label': 'Deepfake', 'score': 0.09433912485837936}]
# fake (18).jpg: [{'label': 'Realism', 'score': 0.5241382122039795}, {'label': 'Deepfake', 'score': 0.4758617579936981}]
# fake (19).jpg: [{'label': 'Deepfake', 'score': 0.6495222449302673}, {'label': 'Realism', 'score': 0.35047775506973267}]
# fake (2).jpg: [{'label': 'Deepfake', 'score': 0.5317850112915039}, {'label': 'Realism', 'score': 0.4682149887084961}]
# fake (20).jpg: [{'label': 'Deepfake', 'score': 0.5156546235084534}, {'label': 'Realism', 'score': 0.48434531688690186}]
# fake (21).jpg: [{'label': 'Deepfake', 'score': 0.5421609282493591}, {'label': 'Realism', 'score': 0.4578390121459961}]
# fake (22).jpg: [{'label': 'Deepfake', 'score': 0.7690882086753845}, {'label': 'Realism', 'score': 0.23091177642345428}]
# fake (23).jpg: [{'label': 'Deepfake', 'score': 0.6730009317398071}, {'label': 'Realism', 'score': 0.32699909806251526}]
# fake (24).jpg: [{'label': 'Realism', 'score': 0.7542576193809509}, {'label': 'Deepfake', 'score': 0.24574239552021027}]
# fake (25).jpg: [{'label': 'Deepfake', 'score': 0.5581347942352295}, {'label': 'Realism', 'score': 0.4418652057647705}]
# fake (3).jpg: [{'label': 'Deepfake', 'score': 0.5639458298683167}, {'label': 'Realism', 'score': 0.43605417013168335}]
# Real (18).jpg: [{'label': 'Realism', 'score': 0.5142302513122559}, {'label': 'Deepfake', 'score': 0.48576974868774414}]
# Real (19).jpg: [{'label': 'Realism', 'score': 0.7916592359542847}, {'label': 'Deepfake', 'score': 0.20834074914455414}]
# Real (2).jpg: [{'label': 'Realism', 'score': 0.6879087090492249}, {'label': 'Deepfake', 'score': 0.31209126114845276}]
# Real (20).jpg: [{'label': 'Realism', 'score': 0.9009425044059753}, {'label': 'Deepfake', 'score': 0.09905751794576645}]
# Real (21).jpg: [{'label': 'Realism', 'score': 0.67043536901474}, {'label': 'Deepfake', 'score': 0.3295646607875824}]
# Real (22).jpg: [{'label': 'Realism', 'score': 0.6840177774429321}, {'label': 'Deepfake', 'score': 0.31598225235939026}]
# Real (23).jpg: [{'label': 'Realism', 'score': 0.5685814023017883}, {'label': 'Deepfake', 'score': 0.43141859769821167}]
# Real (24).jpg: [{'label': 'Deepfake', 'score': 0.8495873212814331}, {'label': 'Realism', 'score': 0.15041260421276093}]
# Real (25).jpg: [{'label': 'Realism', 'score': 0.5957533121109009}, {'label': 'Deepfake', 'score': 0.4042466878890991}]
# Real (3).jpg: [{'label': 'Realism', 'score': 0.8342636823654175}, {'label': 'Deepfake', 'score': 0.1657363325357437}]
# Real (4).jpg: [{'label': 'Realism', 'score': 0.844787061214447}, {'label': 'Deepfake', 'score': 0.1552128940820694}]
# Real (5).jpg: [{'label': 'Deepfake', 'score': 0.7773925065994263}, {'label': 'Realism', 'score': 0.22260744869709015}]
# Real (6).jpg: [{'label': 'Deepfake', 'score': 0.799903929233551}, {'label': 'Realism', 'score': 0.2000960260629654}]
# Real (7).jpg: [{'label': 'Realism', 'score': 0.5084076523780823}, {'label': 'Deepfake', 'score': 0.4915923476219177}]
# Real (8).jpg: [{'label': 'Realism', 'score': 0.5321282148361206}, {'label': 'Deepfake', 'score': 0.4678717851638794}]
# Real (9).jpg: [{'label': 'Deepfake', 'score': 0.8671442866325378}, {'label': 'Realism', 'score': 0.13285577297210693}]
# realgedan (1).png: [{'label': 'Deepfake', 'score': 0.6036788821220398}, {'label': 'Realism', 'score': 0.3963211476802826}]
# realgedan (2).png: [{'label': 'Realism', 'score': 0.748123049736023}, {'label': 'Deepfake', 'score': 0.25187695026397705}]
# realgedan (3).png: [{'label': 'Realism', 'score': 0.5603474974632263}, {'label': 'Deepfake', 'score': 0.4396524727344513}]
# realgedan (4).png: [{'label': 'Deepfake', 'score': 0.707330584526062}, {'label': 'Realism', 'score': 0.29266947507858276}]
# realgedan (5).png: [{'label': 'Realism', 'score': 0.7733778953552246}, {'label': 'Deepfake', 'score': 0.22662213444709778}]
