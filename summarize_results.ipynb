# %%
from summarize_results import create_results_summary

summary = create_results_summary(
    results_dir="Results",
    output_dir="Results/Summary",
    output_name="model_results_summary",
    decimals=4,
    include_counts=False,
    write_xlsx=True,
    print_markdown=True,
)
# Out:
# | Model | 20K_real_and_deepfake_images | DeepDetect-2025 | Deepfake-vs-Real-v2 | gravex200k | nuriachandra_Deepfake-Eval-2024 |
# | --- | --- | --- | --- | --- | --- |
# | CHELSEA234_M2F2_Det | Acc: 0.7620<br>Prec: 0.7379<br>Rec: 0.6799<br>F1: 0.7077 | Acc: 0.8065<br>Prec: 0.9277<br>Rec: 0.6317<br>F1: 0.7516 | Acc: 0.7130<br>Prec: 0.8102<br>Rec: 0.5509<br>F1: 0.6558 | Acc: 0.5854<br>Prec: 0.7943<br>Rec: 0.2305<br>F1: 0.3573 | Acc: 0.4959<br>Prec: 0.6699<br>Rec: 0.3440<br>F1: 0.4545 |
# | CommunityForensics-DeepfakeDet-ViT_TEST | Acc: 0.5018<br>Prec: 0.4482<br>Rec: 0.7601<br>F1: 0.5639 | Acc: 0.4813<br>Prec: 0.4688<br>Rec: 0.8945<br>F1: 0.6152 | Acc: 0.4589<br>Prec: 0.4724<br>Rec: 0.7721<br>F1: 0.5862 | Acc: 0.4901<br>Prec: 0.4942<br>Rec: 0.8439<br>F1: 0.6234 | Acc: 0.5953<br>Prec: 0.6491<br>Rec: 0.7341<br>F1: 0.6890 |
# ...
